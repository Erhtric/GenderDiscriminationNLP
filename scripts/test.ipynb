# %%
import sqlite3
import sys
import codecs
import os
from tqdm import tqdm 

embedding_path = os.path.join("c:\\Users\\peppe\\UNIBO\\Ethics for AI\\presentation\\unbiasing_nlp_embeddings", "embeddings")

input = open(os.path.join(embedding_path, "itwac128.tsv"), 'r')
input.readline()
# Out:
# ',\t0.07894955575466156\t0.14726392924785614\t-0.02549535222351551\t-0.1030670627951622\t0.29876071214675903\t0.16540758311748505\t0.07469084113836288\t-0.07697086781263351\t0.0702752098441124\t0.11363702267408371\t0.24066190421581268\t0.08481516689062119\t-0.07487411051988602\t-0.04158183932304382\t-0.19257141649723053\t0.09319159388542175\t0.03810315951704979\t0.2088109403848648\t-0.010586661286652088\t-0.05295725539326668\t0.02451690472662449\t0.10665421187877655\t0.12369587272405624\t-0.017060186713933945\t0.04708313196897507\t-0.06287568062543869\t-0.058304257690906525\t-0.0022125367540866137\t0.03691359981894493\t-0.024471918120980263\t-0.016908179968595505\t0.03776680305600166\t0.01946374773979187\t0.06015032157301903\t-0.09182882308959961\t-0.08895620703697205\t0.14832399785518646\t0.11219285428524017\t-0.0699351504445076\t-0.07112898677587509\t-0.05571139603853226\t0.021534133702516556\t0.06927203387022018\t-0.18049469590187073\t0.02232608012855053\t-0.07477734982967377\t0.0
# ...

# %%
for i in n:
    print(i)
# Out:
# (1247492,)
